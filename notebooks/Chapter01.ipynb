// %% [markdown]
// # Chapter 1 - Hello, C#! Welcome, .NET!
// Mixing *rich* **text** and code is cool!

// %%
#!about
// Out:
// <table><tbody><tr><td><img src="......" width="125em"></img></td><td style="line-height:.8em"><p style="font-size:1.5em"><b>.NET Interactive</b></p><p>&#169; 2020 Microsoft Corporation</p><p><b>Version: </b>1.0.216102+74efcc062935e1051b22671db4250bd855402d96</p><p><b>Build date: </b>2021-03-11T22:38:58.0000000Z</p><p><a href="https://github.com/dotnet/interactive">https://github.com/dotnet/interactive</a></p></td></tr></tbody></table>

// %%
Console.WriteLine("Hello, .NET Interactive!")
// Out:
// Hello, .NET Interactive!

// %%
var number = 8;

// %%
Console.WriteLine(number);
// Out:
// 8
